# %%
import pandas as pd
import numpy as np

df = pd.read_csv('survey_results_public.csv', index_col='ResponseId')
df.columns
# Out:
# Index(['Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
schema_df = pd.read_csv('survey_results_schema.csv', index_col='qname')
schema_df
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# Q310                  QID310
# Q120                  QID312
# S1                      QID1
# MainBranch              QID2
# Age                   QID127
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# TechList              QID322
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# ...

# %%
df.iloc[[0,5], 4]
# Out:
# ResponseId
# 1       NaN
# 6    Remote
# Name: RemoteWork, dtype: object

# %% [markdown]
# df['MainBranch'].value_counts()

# %%
df.loc[0:4, 'MainBranch':'LearnCode']
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1                            None of these  18-24 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  45-54 years old
# 4           I am a developer by profession  25-34 years old
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                                Remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                              CodingActivities  \
# ResponseId
# 1                                                         NaN
# 2           Hobby;Contribute to open-source projects;Boots...
# 3           Hobby;Professional development or self-paced l...
# ...

# %% [markdown]
# **df**.set_index('MainBranch', inplace=True)

# %%
schema_df.loc['YearsCodePro', 'question']
# Out:
# 'NOT including education, how many years have you coded professionally (as a part of your work)?'

# %%
df.columns
# Out:
# Index(['Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
# ...

# %%
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
df.loc[1]
# Out:
# Q120                                           I agree
# MainBranch                               None of these
# Age                                    18-24 years old
# Employment                                         NaN
# RemoteWork                                         NaN
# CodingActivities                                   NaN
# EdLevel                                            NaN
# LearnCode                                          NaN
# LearnCodeOnline                                    NaN
# LearnCodeCoursesCert                               NaN
# YearsCode                                          NaN
# YearsCodePro                                       NaN
# DevType                                            NaN
# OrgSize                                            NaN
# PurchaseInfluence                                  NaN
# TechList                                           NaN
# BuyNewTool                                         NaN
# ...

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                          qid  \
# qname
# AIAcc                 QID324
# AIBen                 QID316
# AIDev                 QID328
# AINext                QID320
# AIOpen                QID321
# AISearch              QID327
# AISelect              QID314
# AISent                QID315
# AITool                QID319
# Age                   QID127
# BuyNewTool            QID279
# CodingActivities      QID297
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Employment            QID296
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# ICorPM                QID287
# Industry              QID326
# Knowledge             QID289
# Knowledge_1           QID289
# Knowledge_2           QID289
# Knowledge_3           QID289
# Knowledge_4           QID289
# ...

# %%
Salary_filter = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[Salary_filter]
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 2           I agree  I am a developer by profession     25-34 years old
# 8           I agree  I am a developer by profession     25-34 years old
# 10          I agree  I am a developer by profession     25-34 years old
# 11          I agree  I am a developer by profession     25-34 years old
# 12          I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 27046       I agree  I am a developer by profession     25-34 years old
# 27047       I agree  I am a developer by profession     18-24 years old
# 27048       I agree     I code primarily as a hobby  Under 18 years old
# 27050       I agree  I am a developer by profession     18-24 years old
# 27055       I agree  I am a developer by profession     25-34 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df['MainBranch']= df['MainBranch'].apply(lambda X:X.lower())

# %%
df
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   none of these  18-24 years old
# 2           I agree  i am a developer by profession  25-34 years old
# 3           I agree  i am a developer by profession  45-54 years old
# 4           I agree  i am a developer by profession  25-34 years old
# 5           I agree  i am a developer by profession  25-34 years old
# ...             ...                             ...              ...
# 27052       I agree     i code primarily as a hobby  35-44 years old
# 27053       I agree  i am a developer by profession  35-44 years old
# 27054       I agree     i code primarily as a hobby  55-64 years old
# 27055       I agree  i am a developer by profession  25-34 years old
# 27056       I agree  i am a developer by profession  35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df.apply(len, axis='columns')
# Out:
# ResponseId
# 1        83
# 2        83
# 3        83
# 4        83
# 5        83
#          ..
# 27052    83
# 27053    83
# 27054    83
# 27055    83
# 27056    83
# Length: 27056, dtype: int64

# %%
df['Q120'].replace({'I agree' : 'I Dont'})
# Out:
# ResponseId
# 1        I Dont
# 2        I Dont
# 3        I Dont
# 4        I Dont
# 5        I Dont
#           ...
# 27052    I Dont
# 27053    I Dont
# 27054    I Dont
# 27055    I Dont
# 27056    I Dont
# Name: Q120, Length: 27056, dtype: object

# %%
df
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   none of these  18-24 years old
# 2           I agree  i am a developer by profession  25-34 years old
# 3           I agree  i am a developer by profession  45-54 years old
# 4           I agree  i am a developer by profession  25-34 years old
# 5           I agree  i am a developer by profession  25-34 years old
# ...             ...                             ...              ...
# 27052       I agree     i code primarily as a hobby  35-44 years old
# 27053       I agree  i am a developer by profession  35-44 years old
# 27054       I agree     i code primarily as a hobby  55-64 years old
# 27055       I agree  i am a developer by profession  25-34 years old
# 27056       I agree  i am a developer by profession  35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df['RemoteWork'].map({'Remote' : 'Work Remotely'})
# Out:
# ResponseId
# 1                  NaN
# 2        Work Remotely
# 3                  NaN
# 4                  NaN
# 5        Work Remotely
#              ...
# 27052              NaN
# 27053              NaN
# 27054              NaN
# 27055              NaN
# 27056    Work Remotely
# Name: RemoteWork, Length: 27056, dtype: object

# %%
df.sort_values (by=['Country', 'CompTotal'], ascending = [True, False] , inplace=True)

# %%
df[['Country', 'CompTotal']].head(50)
# Out:
#                 Country  CompTotal
# ResponseId
# 1335        Afghanistan   210000.0
# 17873       Afghanistan   100000.0
# 2642        Afghanistan      123.0
# 21673       Afghanistan        NaN
# 21498       Afghanistan        NaN
# 26532       Afghanistan        NaN
# 20378       Afghanistan        NaN
# 4410        Afghanistan        NaN
# 14420       Afghanistan        NaN
# 3911        Afghanistan        NaN
# 15959       Afghanistan        NaN
# 10377       Afghanistan        NaN
# 10143       Afghanistan        NaN
# 4222        Afghanistan        NaN
# 2301        Afghanistan        NaN
# 23095       Afghanistan        NaN
# 1095            Albania  9000000.0
# 18600           Albania  1200000.0
# 13784           Albania   280000.0
# 1260            Albania   200000.0
# 14397           Albania   200000.0
# 18743           Albania    40000.0
# 16606           Albania    21600.0
# 14605           Albania    16800.0
# 10269           Albania    14000.0
# ...

# %%
df['CompTotal'].nlargest(10)
# Out:
# ResponseId
# 18464    1.000000e+21
# 15440    4.567887e+12
# 19680    2.239672e+10
# 9176     1.840199e+10
# 11113    1.000000e+10
# 15398    9.149086e+09
# 26289    7.200000e+09
# 1141     7.000000e+09
# 23718    6.000000e+09
# 2888     6.000000e+09
# Name: CompTotal, dtype: float64

# %%
df.nlargest(10, 'CompTotal')
# Out:
#            Q120                      MainBranch                 Age  \
# ResponseId
# 18464       NaN  i am a developer by profession     25-34 years old
# 15440       NaN  i am a developer by profession     25-34 years old
# 19680       NaN  i am a developer by profession     25-34 years old
# 9176        NaN  i am a developer by profession     25-34 years old
# 11113       NaN  i am a developer by profession     35-44 years old
# 15398       NaN  i am a developer by profession  Under 18 years old
# 26289       NaN  i am a developer by profession     25-34 years old
# 1141        NaN  i am a developer by profession     25-34 years old
# 23718       NaN  i am a developer by profession     25-34 years old
# 2888        NaN  i am a developer by profession     25-34 years old
#
#                      Employment                            RemoteWork  \
# ResponseId
# 18464       Employed, full-time                             In-person
# ...

# %%
df['Country'].value_counts()
# Out:
# United States of America                                4308
# Germany                                                 2537
# United Kingdom of Great Britain and Northern Ireland    2008
# India                                                   1593
# France                                                  1025
#                                                         ...
# Liberia                                                    1
# North Korea                                                1
# Niger                                                      1
# Mozambique                                                 1
# Lesotho                                                    1
# Name: Country, Length: 166, dtype: int64

# %%
df['Country'].value_counts(normalize=True)
# Out:
# United States of America                                0.160584
# Germany                                                 0.094569
# United Kingdom of Great Britain and Northern Ireland    0.074850
# India                                                   0.059380
# France                                                  0.038208
#                                                           ...
# Liberia                                                 0.000037
# North Korea                                             0.000037
# Niger                                                   0.000037
# Mozambique                                              0.000037
# Lesotho                                                 0.000037
# Name: Country, Length: 166, dtype: float64
